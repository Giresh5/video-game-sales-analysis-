# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
Data1 = pd.read_csv(r"C:\Users\gires\Downloads\Data-Science-Video-games-sales-dataset-main\Data-Science-Video-games-sales-dataset-main\vgsales.csv")

# %%
Data1
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
Data1.shape
# Out:
# (16598, 11)

# %%
Data1.loc[np.random.choice(Data1.index,700,replace=False),"NA_Sales"] = np.nan
Data1["NA_Sales"].isnull().sum()
# Out:
# np.int64(700)

# %%
Data1.loc[np.random.choice(Data1.index,750,replace=False),"Genre"] = np.nan
Data1["Genre"].isnull().sum()
# Out:
# np.int64(750)

# %%
Data1.loc[np.random.choice(Data1.index,744,replace=False),"Publisher"] = np.nan
Data1["Publisher"].isnull().sum()
# Out:
# np.int64(800)

# %%
Data1.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  15898.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.265592      0.146652      0.077782
# std     4791.853933      5.828981      0.823535      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
Data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         15848 non-null  object
#  5   Publisher     15798 non-null  object
#  6   NA_Sales      15898 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
Data1.isnull().sum().sum()
# Out:
# np.int64(2521)

# %%
Data1.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre           750
# Publisher       800
# NA_Sales        700
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
Data1.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
Data1.tail()
# Out:
#         Rank                                              Name Platform  \
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year     Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16593  2002.0  Platform       Kemco      0.01      0.00       0.0
# 16594  2003.0   Shooter  Infogrames      0.01      0.00       0.0
# 16595  2008.0    Racing  Activision      0.00      0.00       0.0
# 16596  2010.0    Puzzle    7G//AMES      0.00      0.01       0.0
# 16597  2003.0  Platform     Wanadoo      0.01      0.00       0.0
#
#        Other_Sales  Global_Sales
# 16593          0.0          0.01
# 16594          0.0          0.01
# ...

# %% [markdown]
# Filling Null Values

# %%
Data1["Genre"].fillna(Data1["Genre"].mode()[0],inplace=True)
Data1["Genre"].isnull().sum()
# Out:
# np.int64(0)

# %%
NaS_mode = Data1["NA_Sales"].mean()
Data1["NA_Sales"].fillna(NaS_mode,inplace=True)
Data1["NA_Sales"].isnull().sum()
# Out:
# np.int64(0)

# %%
Data1["Publisher"].mode()[0]
Data1["Publisher"].fillna("Electronic Arts",inplace=True)

# %%
Data1["Year"].fillna(Data1["Year"].mode()[0],inplace=True)
Data1["Year"].isnull().sum()
# Out:
# np.int64(0)

# %%
Data1["Year"]=pd.to_numeric(Data1["Year"])

# %%
Data1.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
Data1.duplicated().sum()
# Out:
# np.int64(0)

# %%
Data1["Index"] = np.arange(len(Data1))

# %%
Data1.set_index("Index",inplace=True)

# %%
Data1["Genre"].value_counts()
# Out:
# Genre
# Action          3918
# Sports          2242
# Misc            1654
# Role-Playing    1428
# Shooter         1256
# Adventure       1223
# Racing          1188
# Platform         847
# Simulation       824
# Fighting         818
# Strategy         648
# Puzzle           552
# Name: count, dtype: int64

# %%
Data1.loc[10:20,"Rated"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\gires\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Rated'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 Data1.loc[10:20,"Rated"]
#
# ...

# %%
Data1["Rated"]=Data1["Genre"]

# %%
Data1["Rated"]=Data1["Rated"].replace({"Action":"12+","Shooter":"12+","Fighting":"12+"})
Data1["Rated"]=Data1["Rated"].replace({"Sports":"Any Age Group","Platform":"Any Age Group","Racing":"Any Age Group","Role-Playing":"Any Age Group","Simulation":"Any Age Group","Adventure":"Any Age Group","Strategy":"Any Age Group","Puzzle":"Any Age Group","Misc":"Any Age Group"})

# %%
Data1.iloc[:11,11]
# Out:
# Index
# 0     Any Age Group
# 1     Any Age Group
# 2     Any Age Group
# 3     Any Age Group
# 4     Any Age Group
# 5     Any Age Group
# 6     Any Age Group
# 7     Any Age Group
# 8     Any Age Group
# 9               12+
# 10    Any Age Group
# Name: Rated, dtype: object

# %%
Data1[Data1["Name"].str.contains("Call of Duty: Black Ops")]
# Out:
#        Rank                        Name Platform    Year    Genre  \
# Index
# 31       32     Call of Duty: Black Ops     X360  2010.0   Action
# 33       34   Call of Duty: Black Ops 3      PS4  2015.0  Shooter
# 34       35  Call of Duty: Black Ops II      PS3  2012.0  Shooter
# 35       36  Call of Duty: Black Ops II     X360  2012.0  Shooter
# 40       41     Call of Duty: Black Ops      PS3  2010.0  Shooter
# 101     102   Call of Duty: Black Ops 3     XOne  2015.0  Shooter
# 967     969   Call of Duty: Black Ops 3      PS3  2015.0  Shooter
# 999    1001   Call of Duty: Black Ops 3     X360  2015.0  Shooter
# 1126   1128     Call of Duty: Black Ops       PC  2009.0  Shooter
# 1217   1219  Call of Duty: Black Ops II       PC  2012.0  Shooter
# 1379   1381     Call of Duty: Black Ops      Wii  2010.0  Shooter
# 3211   3213     Call of Duty: Black Ops       DS  2010.0  Shooter
# 4554   4556  Call of Duty: Black Ops II     WiiU  2012.0  Shooter
# ...

# %%
v1 = Data1["Genre"].value_counts() 
v2 = Data1["Genre"].unique()
plt.figure(figsize=(12,6))
plt.pie(v1,labels=v2,autopct="%1.1f%%",shadow=True)
plt.show()

# %%
b = Data1.groupby(["Genre"])["Global_Sales"].max()
plt.figure(figsize=(12,10))
sns.jointplot(b,kind="scatter",color="red")

# %%
c = Data1.groupby(["Genre"])["Publisher"].count()
plt.figure(figsize=(12,5))
sns.barplot(c,color="blue")
plt.grid(True)

# %%
g = Data1["Publisher"].value_counts()
g = g[:10]
g.plot(kind="bar",color="purple")
plt.title("TOP 10 PUBLISHERS")
# Out:
# Text(0.5, 1.0, 'TOP 10 PUBLISHERS')

# %%
e = Data1.sort_values(["NA_Sales"],ascending=False)[["Name","NA_Sales"]]
e = e[:10].set_index("Name")
e.plot(kind="bar",color="blue")
plt.title("Top 10 North America VG Sales")
# Out:
# Text(0.5, 1.0, 'Top 10 North America VG Sales')

# %%
f = Data1.sort_values(["JP_Sales"],ascending=False)[["Name","JP_Sales"]]
f = f[:10].set_index("Name")
f.plot(kind="bar",color='red')
plt.title("Top 10 Japan VG Sales")
# Out:
# Text(0.5, 1.0, 'Top 10 Japan VG Sales')

# %%
h = Data1.groupby(["Platform"])["Publisher"].count()
plt.figure(figsize=(15,5))
plt.plot(h,'g*-.',linewidth=2,markersize=10,markeredgecolor='red',label='')
plt.grid(True)

# %%
sns.barplot(Data1[["Global_Sales","Other_Sales","JP_Sales","EU_Sales","NA_Sales"]])
plt.xlabel("Total Division Of Sales",fontdict={'fontname':'comic sans ms','fontsize':15})
plt.ylabel("Sales Scale",fontdict={'fontname':'comic sans ms','fontsize':15})
plt.title("Total Sales",fontdict={'fontname':'comic sans ms','fontsize':20})
# Out:
# Text(0.5, 1.0, 'Total Sales')

# %%
box = Data1[["Name","Platform","Year","Genre"]]

# %%
plt.figure(figsize=(27,5))
sns.countplot(data=Data1,x="Year",hue="Rated")
# Out:
# <Axes: xlabel='Year', ylabel='count'>

# %%
#x = pd.crosstab(Data1["Year"],Data1["Global_Sales"],aggfunc=max)
plt.figure(figsize=(15,5))
gp=Data1.groupby("Year")[["Global_Sales"]].max().sort_values(by="Global_Sales",ascending=False)
sns.lineplot(gp,palette="cool",dashes=True,markers="+",markeredgecolor="red")
# Out:
# <Axes: xlabel='Year'>

# %%
sns.palplot(sns.color_palette())
